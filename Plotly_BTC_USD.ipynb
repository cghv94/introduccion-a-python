# %% [markdown]
# <a href="https://colab.research.google.com/github/cghv94/introduccion-a-python/blob/main/Plotly_BTC_USD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instalando las librerías

# %%
# !pip install pandas
# !pip install plotly

# %% [markdown]
# Tabla de datos

# %%
import pandas as pd
df = pd.read_csv('Bitcoin USD (BTC-USD)2022-03-10.csv')
df.head()
# Out:
#    Unnamed: 0                 Nombre       Fecha    Apertura      Minimo  \
# 0           1  Bitcoin USD (BTC-USD)  2014-09-17  465.864014  452.421997
# 1           2  Bitcoin USD (BTC-USD)  2014-09-18  456.859985  413.104004
# 2           3  Bitcoin USD (BTC-USD)  2014-09-19  424.102997  384.532013
# 3           4  Bitcoin USD (BTC-USD)  2014-09-20  394.673004  389.882996
# 4           5  Bitcoin USD (BTC-USD)  2014-09-21  408.084991  393.181000
#
#        Maximo      Cierre   Volumen
# 0  468.174011  457.334015  21056800
# 1  456.859985  424.440002  34483200
# 2  427.834991  394.795990  37919700
# 3  423.295990  408.903992  36863600
# 4  412.425995  398.821014  26580100

# %% [markdown]
# Gráfica con plotly

# %%
import plotly.express as px

df = pd.read_csv('Bitcoin USD (BTC-USD)2022-03-10.csv')

fig = px.line(df, x = 'Fecha', y = 'Cierre', title='Bitcoin USD (BTC-USD)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
